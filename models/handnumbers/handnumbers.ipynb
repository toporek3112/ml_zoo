# %% [markdown]
# # MNIST Digit Classification

# %%
# !pip install -r ./requirements.txt
# Out:
# Requirement already satisfied: pillow in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 1)) (12.0.0)
# Requirement already satisfied: pandas in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: numpy in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 3)) (1.23.5)
# Requirement already satisfied: matplotlib in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 4)) (3.10.7)
# Requirement already satisfied: scipy in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 5)) (1.15.3)
# Requirement already satisfied: torchserve in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: torch-model-archiver in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: torch-workflow-archiver in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 8)) (0.2.15)
# Requirement already satisfied: tensorflow==2.12 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 9)) (2.12.0)
# Requirement already satisfied: keras==2.12 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 10)) (2.12.0)
# Requirement already satisfied: jupyterlab_rise in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 11)) (0.43.1)
# Requirement already satisfied: jupyter in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from -r ./requirements.txt (line 12)) (1.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (25.9.23)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (1.76.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (3.15.1)
# Requirement already satisfied: jax>=0.3.15 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (0.4.30)
# Requirement already satisfied: libclang>=13.0.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (3.4.0)
# Requirement already satisfied: packaging in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (4.25.8)
# Requirement already satisfied: setuptools in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorflow==2.12->-r ./requirements.txt (line 9)) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (2.43.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (3.10)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (0.45.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (0.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from pandas->-r ./requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from pandas->-r ./requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from pandas->-r ./requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 4)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 4)) (3.2.5)
# Requirement already satisfied: psutil in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from torchserve->-r ./requirements.txt (line 6)) (7.0.0)
# Requirement already satisfied: enum-compat in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from torch-model-archiver->-r ./requirements.txt (line 7)) (0.0.3)
# Requirement already satisfied: jupyter-server<3,>=2.0.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab_rise->-r ./requirements.txt (line 11)) (2.16.0)
# Requirement already satisfied: jupyterlab-mathjax3 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab_rise->-r ./requirements.txt (line 11)) (4.3.0)
# Requirement already satisfied: jupyterlab<5,>=4.1.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab_rise->-r ./requirements.txt (line 11)) (4.4.7)
# Requirement already satisfied: anyio>=3.1.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.18.1)
# Requirement already satisfied: tornado>=6.2.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (6.5.1)
# Requirement already satisfied: traitlets>=5.6.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (6.31.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (2.2.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.2.4)
# Requirement already satisfied: httpcore==1.* in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.16.0)
# Requirement already satisfied: babel>=2.10 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (4.25.0)
# Requirement already satisfied: notebook in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter->-r ./requirements.txt (line 12)) (7.4.5)
# Requirement already satisfied: jupyter-console in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter->-r ./requirements.txt (line 12)) (6.6.3)
# Requirement already satisfied: ipywidgets in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter->-r ./requirements.txt (line 12)) (8.1.7)
# Requirement already satisfied: sniffio>=1.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (9.7.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.6.0)
# Requirement already satisfied: decorator>=4.3.2 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.2.13)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jax>=0.3.15->tensorflow==2.12->-r ./requirements.txt (line 9)) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jax>=0.3.15->tensorflow==2.12->-r ./requirements.txt (line 9)) (0.5.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (4.5.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.1.1)
# Requirement already satisfied: fqdn in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: isoduration in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: uri-template in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (6.2.0)
# Requirement already satisfied: defusedxml in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: webencodings in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (2.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12->-r ./requirements.txt (line 9)) (3.3.1)
# Requirement already satisfied: lark>=1.2.2 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: pure_eval in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab_rise->-r ./requirements.txt (line 11)) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (2.0.0)
# Requirement already satisfied: pycparser in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (2.5)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipywidgets->jupyter->-r ./requirements.txt (line 12)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from ipywidgets->jupyter->-r ./requirements.txt (line 12)) (3.0.15)
# Requirement already satisfied: arrow>=0.15.0 in /home/up9b7yr/.local/bin/miniconda3/envs/ml_zoo/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab_rise->-r ./requirements.txt (line 11)) (1.4.0)

# %%
# Import tensorflow and related libraries
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import random

# Force TensorFlow to use CPU only - MUST be set before importing tensorflow
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Reduce TensorFlow logging

# Check TensorFlow version
print(f"TensorFlow version: {tf.__version__}")

# Check available devices
print("Available devices:")
for device in tf.config.list_physical_devices():
    print(f"  - {device}")
    
print(f"GPU Available: {len(tf.config.list_physical_devices('GPU')) > 0}")
print(f"Using device: {'GPU' if len(tf.config.list_physical_devices('GPU')) > 0 else 'CPU'}")

# Test CPU execution
test_tensor = tf.constant([1.0, 2.0, 3.0])
print(f"Test tensor device: {test_tensor.device}")
print("CPU-only configuration complete!")
# Out:
# 2025-11-17 20:14:24.019656: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-17 20:14:24.180274: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-17 20:14:24.183787: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-17 20:14:27.285895: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TensorFlow version: 2.12.0
# Available devices:
#   - PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')
# GPU Available: False
# Using device: CPU
# Test tensor device: /job:localhost/replica:0/task:0/device:CPU:0
# CPU-only configuration complete!

# %% [markdown]
# ## 1 MNIST dataset
#
# Let's download and load the dataset and display a few random samples from it:

# %%
# Load the MNIST dataset directly from tensorflow.keras.datasets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize pixel values to [0, 1] range
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Print dataset information
print(f"Training data shape: {x_train.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Test data shape: {x_test.shape}")
print(f"Test labels shape: {y_test.shape}")
# Out:
# Training data shape: (60000, 28, 28)
# Training labels shape: (60000,)
# Test data shape: (10000, 28, 28)
# Test labels shape: (10000,)

# %% [markdown]
# Our training set is made up of 28x28 grayscale images of handwritten digits. Let's visualize what some of these images and their corresponding training labels look like.

# %%
plt.figure(figsize=(10,10))
random_inds = np.random.choice(60000, 36)
for i in range(36):
    plt.subplot(6,6,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    image_ind = random_inds[i]
    plt.imshow(x_train[image_ind], cmap=plt.cm.binary)
    plt.xlabel(y_train[image_ind])

# %% [markdown]
# ## 2 Neural Network for Handwritten Digit Classification
#
# We'll first build a simple neural network consisting of two fully connected layers and apply this to the digit classification task. Our network will ultimately output a probability distribution over the 10 digit classes (0-9).

# %% [markdown]
# ### 2.1 Fully connected neural network architecture

# %%
model_fc = keras.Sequential([
    # first define a Flatten layer
    layers.Flatten(input_shape=(28, 28)),
    # define the first fully connected layer
    layers.Dense(128, activation='relu'),
    # define the second Dense layer to output the classification probabilities
    layers.Dense(10, activation='softmax')
])

# Display model architecture
model_fc.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's take a step back and think about the network we've just created. The first layer in this network, `layers.Flatten`, transforms the format of the images from a 2d-array (28 x 28 pixels), to a 1d-array of 28 * 28 = 784 pixels. You can think of this layer as unstacking rows of pixels in the image and lining them up. There are no learned parameters in this layer; it only reformats the data.
#
# After the pixels are flattened, the network consists of a sequence of two `layers.Dense` layers. These are fully-connected neural layers. The first `Dense` layer has 128 nodes (or neurons) and uses ReLU activation. The second (and last) layer returns an array of probability scores using softmax activation. Each node contains a score that indicates the probability that the current image belongs to one of the handwritten digit classes.
#
# That defines our fully connected model!

# %% [markdown]
# #### Train the model
#
# Before training the model, we need to define a few more settings:
#
# * *Loss function* — This defines how we measure how accurate the model is during training. During training we want to minimize this function, which will "steer" the model in the right direction.
# * *Optimizer* — This defines how the model is updated based on the data it sees and its loss function.
# * *Metrics* — Here we can define metrics used to monitor the training and testing steps. In this example, we'll look at the *accuracy*, the fraction of the images that are correctly classified.
#
# We'll start out by using a stochastic gradient descent (SGD) optimizer initialized with a learning rate of 0.1. Since we are performing a categorical classification task, we'll want to use the [sparse categorical crossentropy loss](https://www.tensorflow.org/api_docs/python/tf/keras/losses/sparse_categorical_crossentropy).

# %%
# Compile the model with optimizer, loss function, and metrics
model_fc.compile(optimizer=keras.optimizers.SGD(learning_rate=0.1),
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])

# %% [markdown]
# We're now ready to train our model, which will involve feeding the training data (`x_train` and `y_train`) into the model, and then asking it to learn the associations between images and labels. We'll also need to define the batch size and the number of epochs, or iterations over the MNIST dataset, to use during training.

# %%
BATCH_SIZE = 64
EPOCHS = 5

# Force execution on CPU device
# with tf.device('/CPU:0'):
#     print("Training on CPU device...")
    
    # Train the model
history_fc = model_fc.fit(x_train, y_train,
                       batch_size=BATCH_SIZE,
                       epochs=EPOCHS,
                       validation_split=0.1,  # Use 10% of training data for validation
                       verbose=1)

    # print("Training completed on CPU!")
# Out:
# Epoch 1/5
# 844/844 [==============================] - 6s 6ms/step - loss: 0.3963 - accuracy: 0.8898 - val_loss: 0.2014 - val_accuracy: 0.9457
# Epoch 2/5
# 844/844 [==============================] - 4s 5ms/step - loss: 0.2135 - accuracy: 0.9390 - val_loss: 0.1592 - val_accuracy: 0.9558
# Epoch 3/5
# 844/844 [==============================] - 5s 5ms/step - loss: 0.1597 - accuracy: 0.9542 - val_loss: 0.1265 - val_accuracy: 0.9650
# Epoch 4/5
# 844/844 [==============================] - 5s 5ms/step - loss: 0.1287 - accuracy: 0.9627 - val_loss: 0.1029 - val_accuracy: 0.9722
# Epoch 5/5
# 844/844 [==============================] - 5s 5ms/step - loss: 0.1081 - accuracy: 0.9689 - val_loss: 0.0927 - val_accuracy: 0.9737

# %% [markdown]
# As the model trains, the loss and accuracy metrics are displayed. With five epochs and a learning rate of 0.1, this fully connected model should achieve an accuracy of approximately 0.97 (or 97%) on the training data.

# %% [markdown]
# #### Evaluate accuracy on the test dataset
#
# Now that we've trained the model, we can ask it to make predictions about a test set that it hasn't seen before. In this example, the `x_test` and `y_test` comprise our test dataset. To evaluate accuracy, we can check to see if the model's predictions match the labels from the test set.

# %%
# Evaluate the model on test data
test_loss, test_accuracy = model_fc.evaluate(x_test, y_test, verbose=0)

print(f"Test Error:")
print(f" Accuracy: {(100 * test_accuracy):>0.1f}%, Avg loss: {test_loss:>8f}")

# Optional: Get more detailed predictions
predictions = model_fc.predict(x_test, verbose=0)
predicted_classes = np.argmax(predictions, axis=1)

# Show some examples of correct and incorrect predictions
correct_predictions = predicted_classes == y_test
print(f"\nCorrect predictions: {np.sum(correct_predictions)}/{len(y_test)}")
print(f"Accuracy: {np.mean(correct_predictions)*100:.2f}%")
# Out:
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.105523
#
# Correct predictions: 9680/10000
# Accuracy: 96.80%

# %% [markdown]
# ### 2.2 Convolutional Neural Network (CNN) for handwritten digit classification

# %% [markdown]
# We will now build a CNN composed of two convolutional layers and pooling layers, followed by two fully connected layers, and ultimately output a probability distribution over the 10 digit classes (0-9). The CNN we will be building is depicted below:

# %% [markdown]
# #### Define the CNN model
#
# We'll use the same training and test datasets as before, and proceed similarly as our fully connected network to define and train our new CNN model.

# %%
model_cnn = keras.Sequential([
                # First convolutional layer - note the input shape for the first layer
                layers.Conv2D(filters=32, kernel_size=3, strides=1, padding='same', 
                             activation='relu', input_shape=(28, 28, 1)),

                # First max pooling layer
                layers.MaxPooling2D(pool_size=2, strides=2),

                # Second convolutional layer
                layers.Conv2D(filters=64, kernel_size=3, strides=1, padding='same', 
                             activation='relu'),

                # Second max pooling layer
                layers.MaxPooling2D(pool_size=2, strides=2),

                # Flatten for the dense layers
                layers.Flatten(),

                # Fully connected layer
                layers.Dense(128, activation='relu'),

                # Output layer for classification (10 digits)
                layers.Dense(10, activation='softmax')
            ])
    
# Display model architecture
model_cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_2 (Dense)             (None, 128)               401536
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 421,642
# Trainable params: 421,642
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train and test the CNN model
#
# Now, as before, we can define the loss function, optimizer, and metrics, with an optimizer and learning rate of choice:

# %%
# Compile the CNN model with optimizer, loss function, and metrics
model_cnn.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),  # You can experiment (e.g., SGD, RMSprop)
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])

print("CNN model compiled successfully!")
# Out:
# CNN model compiled successfully!

# %% [markdown]
# As was the case with the fully connected model, we can train our CNN using the training loop from above.

# %%
# Train the CNN model with the same batch_size and number of epochs
BATCH_SIZE = 64
EPOCHS = 5

# Prepare data for CNN - need to add channel dimension and reshape for TensorFlow
# TensorFlow expects (height, width, channels) format
x_train_cnn = x_train.reshape(-1, 28, 28, 1)  # Add channel dimension
x_test_cnn = x_test.reshape(-1, 28, 28, 1)   # Add channel dimension

# Force execution on CPU device
with tf.device('/CPU:0'):
    print("Training CNN on CPU device...")
    
    # Train the CNN model
    cnn_history = model_cnn.fit(x_train_cnn, y_train,
                               batch_size=BATCH_SIZE,
                               epochs=EPOCHS,
                               validation_split=0.1,  # Use 10% of training data for validation
                               verbose=1)
    
    print("CNN training completed on CPU!")
# Out:
# Training CNN on CPU device...
# Epoch 1/5
# 844/844 [==============================] - 29s 33ms/step - loss: 0.1499 - accuracy: 0.9546 - val_loss: 0.0588 - val_accuracy: 0.9815
# Epoch 2/5
# 844/844 [==============================] - 24s 28ms/step - loss: 0.0456 - accuracy: 0.9858 - val_loss: 0.0470 - val_accuracy: 0.9868
# Epoch 3/5
# 844/844 [==============================] - 26s 31ms/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 0.0321 - val_accuracy: 0.9905
# Epoch 4/5
# 844/844 [==============================] - 25s 30ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 0.0380 - val_accuracy: 0.9888
# Epoch 5/5
# 844/844 [==============================] - 27s 31ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.0290 - val_accuracy: 0.9923
# CNN training completed on CPU!

# %% [markdown]
# Great! Now that we've trained the model, let's evaluate it on the test dataset :

# %%
# Evaluate the CNN model on test data
with tf.device('/CPU:0'):
    test_loss_cnn, test_accuracy_cnn = model_cnn.evaluate(x_test_cnn, y_test, verbose=0)

    print(f"[CNN] Test Results:")
    print(f"  Accuracy: {(100 * test_accuracy_cnn):>0.1f}%")
    print(f"  Average Loss: {test_loss_cnn:>8f}")

    # Optional: Get more detailed predictions
    predictions_cnn = model_cnn.predict(x_test_cnn, verbose=0)
    predicted_classes_cnn = np.argmax(predictions_cnn, axis=1)

    # Show some examples of correct and incorrect predictions
    correct_predictions_cnn = predicted_classes_cnn == y_test
    print(f"\nCorrect predictions: {np.sum(correct_predictions_cnn)}/{len(y_test)}")
    print(f"CNN Test Accuracy: {np.mean(correct_predictions_cnn)*100:.2f}%")
# Out:
# [CNN] Test Results:
#   Accuracy: 99.1%
#   Average Loss: 0.022167
#
# Correct predictions: 9913/10000
# CNN Test Accuracy: 99.13%

# %% [markdown]
# ## 3 Model saving and testing
# Now that we have trained our CNN models, let's save it in the TensorFlow SavedModel format so it can be served using TensorFlow Serving in our Docker container.

# %%
# Create the directory structure for TensorFlow Serving
# Define the model save path according to TensorFlow Serving conventions
# The path structure should be: model_name/version_number/
model_fc_path = "./model/0/"
model_cnn_path = "./model/1/"

# Create the directory if it doesn't exist
os.makedirs(model_fc_path, exist_ok=True)
os.makedirs(model_cnn_path, exist_ok=True)

# Save the trained CNN model in SavedModel format for TensorFlow Serving
tf.saved_model.save(model_fc, model_fc_path)
tf.saved_model.save(model_cnn, model_cnn_path)

print(f"Model exported successfully at: {model_cnn_path}")

print("Directory structure:")
for root, dirs, files in os.walk("./model"):
    level = root.replace("./model", '').count(os.sep)
    indent = ' ' * 2 * level
    print(f"{indent}{os.path.basename(root)}/")
    subindent = ' ' * 2 * (level + 1)
    for file in files:
        print(f"{subindent}{file}")
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./handnumbers/0/assets
# INFO:tensorflow:Assets written to: ./handnumbers/0/assets
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./handnumbers/1/assets
# INFO:tensorflow:Assets written to: ./handnumbers/1/assets
# Model exported successfully at: ./handnumbers/1/
# Directory structure:
# handnumbers/
#   1/
#     fingerprint.pb
#     saved_model.pb
#     variables/
#       variables.data-00000-of-00001
#       variables.index
#     assets/
#   0/
#     fingerprint.pb
#     saved_model.pb
#     variables/
#       variables.data-00000-of-00001
#       variables.index
#     assets/

# %% [markdown]
# ### Test the saved model
#
# Let's verify that our saved model works correctly by loading it and making a test prediction:

# %%
# Load the saved model to verify it works
# loaded_model = tf.saved_model.load(model_fc_path)
loaded_model = tf.saved_model.load(model_cnn_path)

# Get the inference function
infer = loaded_model.signatures["serving_default"]

# Test with a sample from the test set
test_image = x_test_cnn[0:1]  # Take the first test image
test_label = y_test[0]

# Make prediction with original model
original_prediction = model_cnn.predict(test_image, verbose=0)
original_class = np.argmax(original_prediction)

# Make prediction with loaded model (SavedModel format)
test_tensor = tf.convert_to_tensor(test_image, dtype=tf.float32)
loaded_prediction_dict = infer(test_tensor)

# Extract the prediction array 
loaded_prediction_key = list(loaded_prediction_dict.keys())[0]
loaded_prediction = loaded_prediction_dict[loaded_prediction_key].numpy()
loaded_class = np.argmax(loaded_prediction)

print(f"Original model prediction: {original_class}")
print(f"Loaded model prediction: {loaded_class}")
print(f"Actual label: {test_label}")
print(f"Predictions match: {original_class == loaded_class}")

# Display the test image
plt.figure(figsize=(6, 2))
plt.subplot(1, 2, 1)
plt.imshow(test_image[0].squeeze(), cmap='gray')
plt.title(f'Test Image\nActual: {test_label}')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.bar(range(10), loaded_prediction[0])
plt.title('Model Confidence')
plt.xlabel('Digit')
plt.ylabel('Probability')
plt.xticks(range(10))
plt.tight_layout()
plt.show()

print("✅ Model saved and verified successfully!")
print(f"SavedModel signatures: {list(loaded_model.signatures.keys())}")
print(f"Output tensor name: {loaded_prediction_key}")
# Out:
# Original model prediction: 7
# Loaded model prediction: 7
# Actual label: 7
# Predictions match: True
# ✅ Model saved and verified successfully!
# SavedModel signatures: ['serving_default']
# Output tensor name: dense_3
